# %% [markdown]
# ![Test Image 1](https://cisp.cachefly.net/assets/articles/images/resized/0000915734_resized_diamonds1022.jpg)

# %% [markdown]
# ## Diamonds
#
# ## Background/Story
#
# Diamonds, we all know and love them, but other than how pretty they are the next thing in your head might be how expensive they are. In our day and age diamonds are everywhere, an individual cannot hope to be married without having to buy one or multple diamonds. Having a wife myself I have had to purchase diamonds in the past but I never really understood what gives a diamond its price. In this project I aim to assist an everyday consumer like you and I (assuming you aren't a millionaire) understand better what gives a diamond its value.

# %% [markdown]
# ## Data
#
# The data used in this project derives from data acquired from Kaggle. The data sat contains about 54000 diamonds with 11 columns of attributes. The data does not provide what markets and when these diamonds were sold.
#
# The dataset I used has two distinct classifications for the diamond charateristics:
# Numerical:
#           * Carat = weight of the diamond which ranges from 0.2 to 5.
#           * Depth = percentage of depth in a diamond which ranges from 43 to 79.
#           * Price = price in USD which ranges from $326 to $18823
# Categorical:
#           * Cut = quality of the cut ranging from Fair, Good, Very Good, Premium, Ideal in order.
#           * Clarity = clarity of the diamond ranging from worst to best I1, SI2, SI1, VS2, VS1, VVS2, VVS1, IF
#           * Color = color of diamond ranging from worst to best J to D

# %% [markdown]
# ![GIA%20Diamond%20Chart.jpg](attachment:GIA%20Diamond%20Chart.jpg)
# Although not completely matching our data this imagine should give you a general idea of the characteristics in a diamond.

# %% [markdown]
# ## Exploratory Data Analysis
#
# Like I explained in the background I do not know much about diamond pricing to the first thing I wanted to see what how carats affect the price in a diamond so I made a scatter plot to see the data.
#
# ![Diamond%20Carat%20VS%20Price%20EDA-3.png](attachment:Diamond%20Carat%20VS%20Price%20EDA-3.png)

# %% [markdown]
# In this scatter plot you can see the average price of diamonds vs carats. As expected theres a trend up with price increasing with the carats. This scatter plot brought to my attention other things however.It is important to note that majority of diamonds sold are less than 3 carats and a big portion of those sold are not even a carat. In fact in this sample of diamonds 36,438 of them are under a carat which is 67%. This makes me feel better about not buying my wife a carat diamond! Also worth noting is that past 3 carats not many diamonds are sold only 0.05% or 32 diamonds are over 3 carats!

# %% [markdown]
# ## Individual Characteristic Analysis
# ## Non Numerical Data
# Next I examined each characteristic to see if there was any trends between them and the price.
# I used diamonds under $10000 so about 48000 diamonds.

# %% [markdown]
# ### Diamond Cut

# %% [markdown]
# ![Diamond%20Cut%20VS%20Price-3.png](attachment:Diamond%20Cut%20VS%20Price-3.png)

# %% [markdown]
# This bar chart shows up the average price of diamonds of each quality of cut and surprisingly diamonds with very good quality (which is the highest) are in average a lower price than diamonds of the lowest quality cut. Also in the middle you see diamonds with the Ideal cut quality would provide the most bang for your buck it is the middle quality but has the lowest average price of all diamond cuts. This ca

# %% [markdown]
# ### Diamond Clarity

# %% [markdown]
# ![Diamond%20Clarity%20VS%20Price.png](attachment:Diamond%20Clarity%20VS%20Price.png)

# %% [markdown]
# In this bar graph we see that

# %% [markdown]
# ### Diamond Color
